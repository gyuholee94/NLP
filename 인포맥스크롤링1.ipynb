# %% [markdown]
# <a href="https://colab.research.google.com/github/gyuholee94/NLP/blob/master/%EC%9D%B8%ED%8F%AC%EB%A7%A5%EC%8A%A4%ED%81%AC%EB%A1%A4%EB%A7%811.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://news.einfomax.co.kr/news/articleList.html?page=3247&total=97382&sc_area=A&view_type=sm&sc_sdate=2015-01-01&sc_edate=2020-07-11&sc_order_by=E&sc_word=%EA%B8%88%EB%A6%AC&sc_andor=OR&sc_word2=]'
# query = {
#     'page':'3247',
#     'total':'97382',
#     'box_idxno' : '',
#     'sc_area':'A',
#     'view_type':'sm',
#     'sc_section_code' :'',
#     'sc_level' :'',
#     'sc_article_type' :'',
#     'sc_sdate' : '2015-01-01',
#     'sc_edate' : '2020-07-11',
#     'sc_order_by' : 'E',
#     'sc_word' : '%EA%B8%88%EB%A6%AC',
#     'sc_andor' : 'OR',
#     'sc_word2' : ''
# }
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
resp.text
# Out:
# '<!doctype html>\n<html class="no-js" lang="ko" dir="ltr">\n<head>\n<meta charset="utf-8">\n<meta http-equiv="x-ua-compatible" content="ie=edge">\n<meta name="viewport" content="width=1080">\n<meta name="apple-mobile-web-app-title" content="연합인포맥스" />\n<!-- 메타태그정보 //-->\n<meta name="description" content="금융정보 전문업체, 인터넷 실시간 뉴스정보, 금융생방송 프로그램, 고객지원 등 안내."/>\n<meta property="og:title" content="연합인포맥스"/>\n<meta property="og:site_name" content="연합인포맥스"/>\n<meta property="og:image" content="http://news.einfomax.co.kr/image/logo/snslogo_20180927054608.jpg" />\n<meta property="og:url"\tcontent="http://news.einfomax.co.kr" />\n<meta property="og:description" content="금융정보 전문업체, 인터넷 실시간 뉴스정보, 금융생방송 프로그램, 고객지원 등 안내." />\n<meta name="twitter:card" content="summary"/>\n<meta name="twitter:title" content="연합인포맥스"/>\n<meta name="twitter:description" content="금융정보 전문업체, 인터넷 실시간 뉴스정보, 금융생방송 프로그램, 고객지원 등 안내."/>\n<meta name="twitter:image:src" content="http://news.einfomax.co.kr/image/logo/snslogo_20180
# ...

# %%
resp.content
# Out:
# b'<!doctype html>\n<html class="no-js" lang="ko" dir="ltr">\n<head>\n<meta charset="utf-8">\n<meta http-equiv="x-ua-compatible" content="ie=edge">\n<meta name="viewport" content="width=1080">\n<meta name="apple-mobile-web-app-title" content="\xec\x97\xb0\xed\x95\xa9\xec\x9d\xb8\xed\x8f\xac\xeb\xa7\xa5\xec\x8a\xa4" />\n<!-- \xeb\xa9\x94\xed\x83\x80\xed\x83\x9c\xea\xb7\xb8\xec\xa0\x95\xeb\xb3\xb4 //-->\n<meta name="description" content="\xea\xb8\x88\xec\x9c\xb5\xec\xa0\x95\xeb\xb3\xb4 \xec\xa0\x84\xeb\xac\xb8\xec\x97\x85\xec\xb2\xb4, \xec\x9d\xb8\xed\x84\xb0\xeb\x84\xb7 \xec\x8b\xa4\xec\x8b\x9c\xea\xb0\x84 \xeb\x89\xb4\xec\x8a\xa4\xec\xa0\x95\xeb\xb3\xb4, \xea\xb8\x88\xec\x9c\xb5\xec\x83\x9d\xeb\xb0\xa9\xec\x86\xa1 \xed\x94\x84\xeb\xa1\x9c\xea\xb7\xb8\xeb\x9e\xa8, \xea\xb3\xa0\xea\xb0\x9d\xec\xa7\x80\xec\x9b\x90 \xeb\x93\xb1 \xec\x95\x88\xeb\x82\xb4."/>\n<meta property="og:title" content="\xec\x97\xb0\xed\x95\xa9\xec\x9d\xb8\xed\x8f\xac\xeb\xa7\xa5\xec\x8a\xa4"/>\n<meta property="og:si
# ...

# %%
soup = BeautifulSoup(resp.content, 'lxml')

# %%
a_tag = soup.select('section div div.list-titles a')
a_tag
# Out:
# [<a href="/news/articleView.html?idxno=179710" target="_top"><strong>포캐스트 "韓, 8월 금리동결…인하 가능성 열어둘 것"</strong></a>,
#  <a href="/news/articleView.html?idxno=179709" target="_top"><strong>美금리인상, 장기채 매수 타이밍인 이유</strong></a>,
#  <a href=""></a>]

# %%
import re
re.findall("href\=\"(.+?)\"", str(a_tag))
# Out:
# ['/news/articleView.html?idxno=179710', '/news/articleView.html?idxno=179709']
