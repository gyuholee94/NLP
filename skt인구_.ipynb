# %% [markdown]
# <a href="https://colab.research.google.com/github/gyuholee94/NLP/blob/master/skt%EC%9D%B8%EA%B5%AC_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#한국어 폰트 설정
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 3s (3,101 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
#임포트와 구글마운트
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#데이터 연결(성별나이)
age1902= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_201902.CSV', sep = '|')
age1903= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_201903.CSV', sep = '|')
age1904= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_201904.CSV', sep = '|')
age1904= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_201905.CSV', sep = '|')
age2002= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_202002.CSV', sep = '|')
age2003= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_202003.CSV', sep = '|')
age2004= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_202004.CSV', sep = '|')
age2005= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_202005.CSV', sep = '|')

# %%
#데이터 연결(시간)
time1902= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_201902.CSV', sep = '|')
time1903= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_201903.CSV', sep = '|')
time1904= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_201904.CSV', sep = '|')
time1905= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_201905.CSV', sep = '|')
time2002= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_202002.CSV', sep = '|')
time2003= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_202003.CSV', sep = '|')
time2004= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_202004.CSV', sep = '|')
time2005= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_202005.CSV', sep = '|')

# %% [markdown]
# #완성된 함수

# %%
def Drawing(df, day, dong):
  df1= df[69*(day-1):69*(day-1)+15]
  df2= df[69*(day-1)+15:69*(day-1)+34]
  df3= df[69*(day-1)+34:69*(day-1)+46]
  df4= df[69*(day-1)+46:69*(day-1)+69]
  df_seoul = pd.concat([df1, df2])
  df_deagu = pd.concat([df3, df4])

  df1 = df1[df1['HDONG_NM']==str(dong)]
  df2 = df2[df2['HDONG_NM']==str(dong)]
  df3 = df3[df3['HDONG_NM']==str(dong)]
  df4 = df4[df1['HDONG_NM']==str(dong)]
  return df1, df2, df3, df4

# %%
Drawing(time2003, 4, '동인동')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-13-cc0d8fc04089> in <module>()
# ----> 1 Drawing(time2003, 4, '동인동')
#
# <ipython-input-12-9ef23c3af2a9> in Drawing(df, day, dong)
#      10   df2 = df2[df2['HDONG_NM']==str(dong)]
#      11   df3 = df3[df3['HDONG_NM']==str(dong)]
# ---> 12   df4 = df4[df1['HDONG_NM']==str(dong)]
#      13   return df1, df2, df3, df4
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
# ...

# %%
# def Drawing(df, day, dong):
#   df1= df[69*(day-1):69*(day-1)+15]
#   df2= df[69*(day-1)+15:69*(day-1)+34]
#   df3= df[69*(day-1)+34:69*(day-1)+46]
#   df4= df[69*(day-1)+46:69*(day-1)+69]
#   df_seoul = pd.concat([df1, df2])
#   df_deagu = pd.concat([df3, df4])

#   df1 = df1[df1['HDONG_NM']=='{}'.format(dong)]
#   df2 = df2[df2['HDONG_NM']=='{}'.format(dong)]
#   df3 = df3[df3['HDONG_NM']=='{}'.format(dong)]
#   df4 = df4[df1['HDONG_NM']=='{}'.format(dong)]

#   df1.iloc[:,4:].T.plot(figsize=(20,10))
#   plt.legend(df1.iloc[:,3])
#   plt.title("Seoul JungGu")
#   plt.xlabel("Time")
#   plt.ylabel("Number of Population")
#   plt.show()

#   df2.iloc[:,4:].T.plot(figsize=(20,10))
#   plt.legend(df2.iloc[:,3])
#   plt.title("Seoul NowonGu")
#   plt.xlabel("Time")
#   plt.ylabel("Number of Population")
#   plt.show()

#   df3.iloc[:,4:].T.plot(figsize=(20,10))
#   plt.legend(df3.iloc[:,3])
#   plt.title("Deagu JungGu")
#   plt.xlabel("Time")
#   plt.ylabel("Number of Population")
#   plt.show()

#   df4.iloc[:,4:].T.plot(figsize=(20,10))
#   plt.legend(df4.iloc[:,3])
#   plt.title("Deagu SusungGu")
#   plt.xlabel("Time")
#   plt.ylabel("Number of Population")
#   plt.show()

# %%
# 4개 구에 대한 그래프 그리는 함수. 원하는 데이터프레임과 날짜넣으면 찾아서표시해줌  
def Drawing(df, day):
  df1= df[69*(day-1):69*(day-1)+15]
  df2= df[69*(day-1)+15:69*(day-1)+34]
  df3= df[69*(day-1)+34:69*(day-1)+46]
  df4= df[69*(day-1)+46:69*(day-1)+69]
  df_seoul = pd.concat([df1, df2])
  df_deagu = pd.concat([df3, df4])
  df_total = pd.concat([df_seoul, df_deagu])

  
  df1.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df1.iloc[:,3])
  plt.title("Seoul JungGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.grid()
  plt.show()

  df2.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df2.iloc[:,3])
  plt.title("Seoul NowonGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.grid()
  plt.show()

  df3.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df3.iloc[:,3])
  plt.title("Deagu JungGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.grid()
  plt.show()

  df4.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df4.iloc[:,3])
  plt.title("Deagu SusungGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.grid()
  plt.show()
  
  #서울전체 보고싶으면 아래코드 활성화
  # df_seoul.iloc[:,4:].T.plot(figsize=(20,10))
  # plt.legend(df_seoul.iloc[:,3])
  # plt.title("Seoul")
  # plt.xlabel("Time")
  # plt.ylabel("Number of Population")
  # plt.grid()
  # plt.show()
  
  #대구전체 보고싶으면 아래코드 활성화
  # df_deagu.iloc[:,4:].T.plot(figsize=(20,10))
  # plt.legend(df_deagu.iloc[:,3])
  # plt.title("Deagu")
  # plt.xlabel("Time")
  # plt.ylabel("Number of Population")
  # plt.grid()
  # plt.show()
  
  #전체 보고싶으면 아래코드 활성화
  # df_total.iloc[:,4:].T.plot(figsize=(20,10))
  # plt.legend(df_total.iloc[:,3])
  # plt.title("Total")
  # plt.xlabel("Time")
  # plt.ylabel("Number of Population")
  # plt.grid()
  # plt.show()

# %%
from matplotlib import font_manager
# !apt install fonts-nanum
plt.rc('font', family='NanumMyeongjo')

Drawing(time2003, 8)
Drawing(time2003, 15)
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# findfont: Font family ['NanumMyeongjo'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NanumMyeongjo'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#구별로 합쳐서 볼 수 있는 함수
def TotalDrawing(df, day):
  time_col = df.columns
  
  df1= df[69*(day-1):69*(day-1)+15]
  df2= df[69*(day-1)+15:69*(day-1)+34]
  df3= df[69*(day-1)+34:69*(day-1)+46]
  df4= df[69*(day-1)+46:69*(day-1)+69]

  timepop1=[]
  for i in time_col[4:]:
    timepop1.append(df1[i].sum())

  timepop2=[]
  for i in time_col[4:]:
    timepop2.append(df2[i].sum())

  timepop3=[]
  for i in time_col[4:]:
    timepop3.append(df3[i].sum())

  timepop4=[]
  for i in time_col[4:]:
    timepop4.append(df4[i].sum())

  total_df = pd.DataFrame({'Seoul JungGu' : timepop1,  'Seoul NowonGu' : timepop2, 'Deagu JungGu' : timepop3, 'Daegu SusungGu' : timepop4})

  total_df.plot(figsize=(20,10))
  plt.legend(total_df)
  plt.title("Total")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.grid()
  plt.show()

# %%
TotalDrawing(time1902, 2)

# %%
dong = list(time1902['HDONG_NM'].unique())
dong
# Out:
# ['소공동',
#  '회현동',
#  '명동',
#  '필동',
#  '장충동',
#  '광희동',
#  '을지로동',
#  '신당동',
#  '다산동',
#  '약수동',
#  '청구동',
#  '신당5동',
#  '동화동',
#  '황학동',
#  '중림동',
#  '월계1동',
#  '월계2동',
#  '월계3동',
#  '공릉1동',
#  '공릉2동',
#  '하계1동',
#  '하계2동',
#  '중계본동',
#  '중계1동',
#  '중계4동',
#  '중계2.3동',
#  '상계1동',
#  '상계2동',
#  '상계3.4동',
#  '상계5동',
#  '상계6.7동',
#  '상계8동',
#  '상계9동',
#  '상계10동',
#  '동인동',
#  '삼덕동',
#  '성내1동',
#  '성내2동',
#  '성내3동',
#  '대신동',
#  '남산1동',
#  '남산2동',
#  '남산3동',
#  '남산4동',
#  '대봉1동',
#  '대봉2동',
#  '범어1동',
#  '범어2동',
#  '범어3동',
#  '범어4동',
#  '만촌1동',
#  '만촌2동',
#  '만촌3동',
#  '수성1가동',
#  '수성2.3가동',
#  '수성4가동',
#  '황금1동',
#  '황금2동',
#  '중동',
#  '상동',
#  '파동',
#  '두산동',
#  '지산1동',
#  '지산2동',
#  '범물1동',
#  '범물2동',
#  '고산1동',
#  '고산2동',
#  '고산3동']

# %%
pip install dbfread

# %%
from dbfread import DBF
alt= DBF('/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_행정동.DBF')
alt = pd.DataFrame(alt)
alt
# Out:
#    STD_YYYY    HDONG_CD HDONG_NM  ...    LENGTH           X_COORD           Y_COORD
# 0      2020  2726067000     고산1동  ...  17757.54   128.69963062806  35.8117467030855
# 1      2020  2726068000     고산2동  ...  25763.81  128.677147073408   35.838758403345
# 2      2020  2726069000     고산3동  ...  11274.68  128.714043831276  35.8490479398919
# 3      2020  2726064000      두산동  ...   7777.10  128.620832776346  35.8285656536299
# 4      2020  2726055000     만촌1동  ...   8778.85  128.649513200936  35.8706818518603
# ..      ...         ...      ...  ...       ...               ...               ...
# 64     2020  1114068000      중림동  ...   3500.86  126.966042028799  37.5573555328314
# 65     2020  1114064500      청구동  ...   2696.70  127.015201201613  37.5568631855271
# 66     2020  1114057000       필동  ...   6575.62  126.992276757613  37.5568174037835
# 67     2020  1114067000      황학동  ...   2381.97  127.020846207973  37.5685359648242
# ...

# %% [markdown]
# #아래로는 이런저런 시도들이라 볼필요X

# %% [markdown]
# #나이별 차트

# %%
age_col = age1.columns
age1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-830cbe1af014> in <module>()
# ----> 1 age_col = age1.columns
#       2 age1.head()
#
# NameError: name 'age1' is not defined

# %%
age1902['HDONG_NM'].unique()
# Out:
# array(['소공동', '회현동', '명동', '필동', '장충동', '광희동', '을지로동', '신당동', '다산동',
#        '약수동', '청구동', '신당5동', '동화동', '황학동', '중림동', '월계1동', '월계2동', '월계3동',
#        '공릉1동', '공릉2동', '하계1동', '하계2동', '중계본동', '중계1동', '중계4동', '중계2.3동',
#        '상계1동', '상계2동', '상계3.4동', '상계5동', '상계6.7동', '상계8동', '상계9동',
#        '상계10동', '동인동', '삼덕동', '성내1동', '성내2동', '성내3동', '대신동', '남산1동',
#        '남산2동', '남산3동', '남산4동', '대봉1동', '대봉2동', '범어1동', '범어2동', '범어3동',
#        '범어4동', '만촌1동', '만촌2동', '만촌3동', '수성1가동', '수성2.3가동', '수성4가동',
#        '황금1동', '황금2동', '중동', '상동', '파동', '두산동', '지산1동', '지산2동', '범물1동',
#        '범물2동', '고산1동', '고산2동', '고산3동'], dtype=object)

# %%
test1 = age1902[age_col[4:]].iloc[:1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ef2fb971a684> in <module>()
# ----> 1 test1 = age1902[age_col[4:]].iloc[:1]
#
# NameError: name 'age_col' is not defined

# %%
test1.plot.bar(figsize=(20, 10))
plt.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-0210247c7c2b> in <module>()
# ----> 1 test1.plot.bar(figsize=(20, 10))
#       2 plt.grid()
#       3
#       4 plt.show()
#
# NameError: name 'test1' is not defined

# %% [markdown]
# #시간별 차트

# %%
time1902
# Out:
#       STD_YM   STD_YMD    HDONG_CD  ...   TMST_21  TMST_22  TMST_23
# 0     201902  20190201  1114052000  ...   6047.05  4806.65  2956.11
# 1     201902  20190201  1114054000  ...   9341.24  6884.91  4034.56
# 2     201902  20190201  1114055000  ...   8719.30  7203.45  4845.48
# 3     201902  20190201  1114057000  ...   4088.53  3385.14  1746.28
# 4     201902  20190201  1114058000  ...   2626.12  2415.41  1398.94
# ...      ...       ...         ...  ...       ...      ...      ...
# 1927  201902  20190228  2726066100  ...   1730.08  1278.94   826.15
# 1928  201902  20190228  2726066200  ...   1233.50   986.67   596.44
# 1929  201902  20190228  2726067000  ...   6078.16  4467.96  2746.27
# 1930  201902  20190228  2726068000  ...  10419.95  7859.83  4817.53
# 1931  201902  20190228  2726069000  ...   2728.98  2193.95  1305.95
#
# [1932 rows x 28 columns]

# %%
time_col = time1902.columns
time_col
# Out:
# Index(['STD_YM', 'STD_YMD', 'HDONG_CD', 'HDONG_NM', 'TMST_00', 'TMST_01',
#        'TMST_02', 'TMST_03', 'TMST_04', 'TMST_05', 'TMST_06', 'TMST_07',
#        'TMST_08', 'TMST_09', 'TMST_10', 'TMST_11', 'TMST_12', 'TMST_13',
#        'TMST_14', 'TMST_15', 'TMST_16', 'TMST_17', 'TMST_18', 'TMST_19',
#        'TMST_20', 'TMST_21', 'TMST_22', 'TMST_23'],
#       dtype='object')

# %%
len(time1902['HDONG_CD'].unique())#동의 갯수가 69개니까 나누기 위해 포문을 돌리고, 날짜별로 나눠져서 SUM할 수 있겠다.
# Out:
# 69

# %%
dong = list(time1902['HDONG_NM'].unique())
# Out:
# ['소공동',
#  '회현동',
#  '명동',
#  '필동',
#  '장충동',
#  '광희동',
#  '을지로동',
#  '신당동',
#  '다산동',
#  '약수동',
#  '청구동',
#  '신당5동',
#  '동화동',
#  '황학동',
#  '중림동',
#  '월계1동',
#  '월계2동',
#  '월계3동',
#  '공릉1동',
#  '공릉2동',
#  '하계1동',
#  '하계2동',
#  '중계본동',
#  '중계1동',
#  '중계4동',
#  '중계2.3동',
#  '상계1동',
#  '상계2동',
#  '상계3.4동',
#  '상계5동',
#  '상계6.7동',
#  '상계8동',
#  '상계9동',
#  '상계10동',
#  '동인동',
#  '삼덕동',
#  '성내1동',
#  '성내2동',
#  '성내3동',
#  '대신동',
#  '남산1동',
#  '남산2동',
#  '남산3동',
#  '남산4동',
#  '대봉1동',
#  '대봉2동',
#  '범어1동',
#  '범어2동',
#  '범어3동',
#  '범어4동',
#  '만촌1동',
#  '만촌2동',
#  '만촌3동',
#  '수성1가동',
#  '수성2.3가동',
#  '수성4가동',
#  '황금1동',
#  '황금2동',
#  '중동',
#  '상동',
#  '파동',
#  '두산동',
#  '지산1동',
#  '지산2동',
#  '범물1동',
#  '범물2동',
#  '고산1동',
#  '고산2동',
#  '고산3동']

# %%
time1902.shape[0]/69
# Out:
# 28.0

# %%
time1903.shape[0]/69
# Out:
# 31.0

# %%
for i in range(int(time1902.shape[0]/69)):
  df1= time1[69*i:69*i+15]
  df2= time1[69*i+15:69*i+34]
  df3= time1[69*i+34:69*i+46]
  df4= time1[69*i+46:69*i+70]
  #함수로 발전시켜보자
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f884de26fae0> in <module>()
#       1 for i in range(int(time1902.shape[0]/69)):
# ----> 2   df1= time1[69*i:69*i+15]
#       3   df2= time1[69*i+15:69*i+34]
#       4   df3= time1[69*i+34:69*i+46]
#       5   df4= time1[69*i+46:69*i+70]
#
# NameError: name 'time1' is not defined

# %%
df1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-1915fbb7ef2c> in <module>()
# ----> 1 df1.shape
#
# NameError: name 'df1' is not defined

# %%
df2.shape

# %%
df3.shape

# %%
df4.shape

# %%
# 원하는 데이터프레임과 날짜를 집어넣으면 서울중구, 서울노원구, 대구중구, 대구수성구로 뽑는 함수
def datepop(df, day):
  df1= df[69*(day-1):69*(day-1)+15]
  df2= df[69*(day-1)+15:69*(day-1)+34]
  df3= df[69*(day-1)+34:69*(day-1)+46]
  df4= df[69*(day-1)+46:69*(day-1)+70]
  df_seoul = pd.concat([df1, df2])
  df_deagu = pd.concat([df3, df4])
  return df1, df2, df3, df4

# %%
sj, sn, dj, ds = datepop(time1902, 1)

# %%
ds
# Out:
#     STD_YM   STD_YMD    HDONG_CD HDONG_NM  ...   TMST_20   TMST_21  TMST_22  TMST_23
# 46  201902  20190201  2726051000     범어1동  ...   4887.52   4560.54  3180.27  1718.66
# 47  201902  20190201  2726052000     범어2동  ...   4284.66   4518.51  2986.73  1715.07
# 48  201902  20190201  2726053000     범어3동  ...   2930.21   2838.38  1982.36  1081.90
# 49  201902  20190201  2726054000     범어4동  ...   3460.13   3999.87  2364.44  1383.55
# 50  201902  20190201  2726055000     만촌1동  ...   5985.15   5644.25  4121.36  2445.85
# 51  201902  20190201  2726056000     만촌2동  ...   3091.71   3085.70  2105.59  1392.10
# 52  201902  20190201  2726056100     만촌3동  ...   1990.91   1972.63  1443.86   844.52
# 53  201902  20190201  2726057000    수성1가동  ...   3853.52   3437.61  2447.78  1588.86
# 54  201902  20190201  2726058000  수성2.3가동  ...   3940.69   3573.31  2482.02  1517.67
# 55  201902  20190201  2726059000    수성4가동  ...   3649.10   3464.96  2584.30  1527.50
# ...

# %%
ds[ds['HDONG_NM']=='범어1동']
# Out:
#     STD_YM   STD_YMD    HDONG_CD HDONG_NM  ...  TMST_20  TMST_21  TMST_22  TMST_23
# 46  201902  20190201  2726051000     범어1동  ...  4887.52  4560.54  3180.27  1718.66
#
# [1 rows x 28 columns]

# %%
#데이터프레임을 집어넣으면 그래프로 그려주는 함수
def drawing(df):
  df.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df.iloc[:,3])
  plt.title("Time Flow")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

# %%
drawing(sj)

# %%
sj, sn, dj, ds=datepop(time1902, 4)
drawing(sj)

# %%
# 4개 구에 대한 그래프 그리는 함수  
def Drawing(df, day):
  df1= df[69*(day-1):69*(day-1)+15]
  df2= df[69*(day-1)+15:69*(day-1)+34]
  df3= df[69*(day-1)+34:69*(day-1)+46]
  df4= df[69*(day-1)+46:69*(day-1)+69]
  df_seoul = pd.concat([df1, df2])
  df_deagu = pd.concat([df3, df4])

  
  df1.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df1.iloc[:,3])
  plt.title("Seoul JungGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

  df2.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df2.iloc[:,3])
  plt.title("Seoul NowonGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

  df3.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df3.iloc[:,3])
  plt.title("Deagu JungGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

  df4.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df4.iloc[:,3])
  plt.title("Deagu SusungGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

# %%
Drawing(time1902, 20), Drawing(time2002, 20)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54924 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54788 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# 4개 구에 대한 그래프 그리는 함수  + 동뽑아서 해주는 함수
def Drawing(df, day, dong):
  df1= df[69*(day-1):69*(day-1)+15]
  df2= df[69*(day-1)+15:69*(day-1)+34]
  df3= df[69*(day-1)+34:69*(day-1)+46]
  df4= df[69*(day-1)+46:69*(day-1)+69]
  df_seoul = pd.concat([df1, df2])
  df_deagu = pd.concat([df3, df4])

  df1 = df1[df1['HDONG_NM']=='{}'.format(dong)]
  df2 = df2[df2['HDONG_NM']=='{}'.format(dong)]
  df3 = df3[df3['HDONG_NM']=='{}'.format(dong)]
  df4 = df4[df1['HDONG_NM']=='{}'.format(dong)]

  df1.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df1.iloc[:,3])
  plt.title("Seoul JungGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

  df2.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df2.iloc[:,3])
  plt.title("Seoul NowonGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

  df3.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df3.iloc[:,3])
  plt.title("Deagu JungGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

  df4.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df4.iloc[:,3])
  plt.title("Deagu SusungGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

# %% [markdown]
# #이런저런 시도

# %%
df0201=time1[time1902['STD_YMD']==20190201]
# df0201['HDONG_CD'][30:]#111, 113, 271, 272
# df0201[df0201['HDONG_CD'][0][:3]==272]
# df0201['HDONG_CD'].str[:3]
#하,,, 이거 왜 안뽑아지지 구별로 묶고싶은데...

# 111-서울중구 시작코드 앞3자리
# 113-노원구 시작코드 앞3자리
# 271-대구중구 시작코드 앞3자리
# 272-대구 수성구 시작코드 앞3자리/

# %%
#19년 2월 1일로 일단 시각화해보자. 동별로 하면 너무 많아서 범례난리나니까 구별로 더해서 하기. 일단 슬라이싱해서 하되, 나중엔 조건문으로 한번에 나누자

# %%
#중구
df_1=df0201[:15]
df_1

# %%
#노원구
df_2=df0201[15:34]
df_2

# %%
df_3 = df0201[34:46]
df_3

# %%
df_4=df0201[46:]
df_4

# %%
#구별로 나눈 데이터프레임을 같은 시간기준으로 더하기->구별 시간당 인구합이 나온다
timepop1=[]
for i in time_col[4:]:
  timepop1.append(df_1[i].sum())

timepop2=[]
for i in time_col[4:]:
  timepop2.append(df_2[i].sum())

timepop3=[]
for i in time_col[4:]:
  timepop3.append(df_3[i].sum())

timepop4=[]
for i in time_col[4:]:
  timepop4.append(df_4[i].sum())

# %%
df_1.append(df_1.sum().rename('Total')).assign(Total=lambda d: d.sum(1))
df_1

# %%
df_1

# %%
sns.lineplot(x=range(24), y = np.array(timepop1))
sns.lineplot(x=range(24), y = np.array(timepop2))
sns.lineplot(x=range(24), y = np.array(timepop3))
sns.lineplot(x=range(24), y = np.array(timepop4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-60997f66a886> in <module>()
# ----> 1 sns.lineplot(x=range(24), y = np.array(timepop1))
#       2 sns.lineplot(x=range(24), y = np.array(timepop2))
#       3 sns.lineplot(x=range(24), y = np.array(timepop3))
#       4 sns.lineplot(x=range(24), y = np.array(timepop4))
#
# NameError: name 'timepop1' is not defined

# %%
sns.lineplot(x=range(24), y = np.array(timepop1))#중구

# %%
sns.lineplot(x=range(24), y = np.array(timepop2))#노원구

# %%
sns.lineplot(x=range(24), y = np.array(timepop3))#대구중구

# %%
sns.lineplot(x=range(24), y = np.array(timepop4))#대구수성구
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-bcc3e78a1003> in <module>()
# ----> 1 sns.lineplot(x=range(24), y = np.array(timepop4))#대구수성구
#
# NameError: name 'timepop4' is not defined

# %%
#서울 중구 혼자 뿔이 나있네...
df_1.iloc[:,4:]

# %%
#중구 190201 동별 인구...명동 소공, 회현동에서 사람들 많이 움직이는구나...
df_1.iloc[:,4:].T.plot(figsize=(20,10))
plt.legend(df_1.iloc[:,3])
plt.title("FLOW")
plt.xlabel("Time")
plt.ylabel("Number of Population")
plt.show()

# %%
df_2.iloc[:,4:].T.plot(figsize=(20,10))
plt.legend(df_2.iloc[:,3])
plt.title("FLOW")
plt.xlabel("Time")
plt.ylabel("Number of Population")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-84c2c0ae756e> in <module>()
# ----> 1 df_2.iloc[:,4:].T.plot(figsize=(20,10))
#       2 plt.legend(df_2.iloc[:,3])
#       3 plt.title("FLOW")
#       4 plt.xlabel("Time")
#       5 plt.ylabel("Number of Population")
#
# NameError: name 'df_2' is not defined

# %%
df_3.iloc[:,4:].T.plot(figsize=(20,10))
plt.legend(df_3.iloc[:,3])
plt.title("FLOW")
plt.xlabel("Time")
plt.ylabel("Number of Population")
plt.show()

# %%
df_4.iloc[:,4:].T.plot(figsize=(20,10))
plt.legend(df_4.iloc[:,3])
plt.title("FLOW")
plt.xlabel("Time")
plt.ylabel("Number of Population")
plt.show()
